# %%
import sys
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
import glob

# %%
src = cv2.imread('./fig2/cow.png')
dst = cv2.imread('./fig2/green.png')

## mask
src_gray = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)
_, mask = cv2.threshold(src_gray, 240, 255, cv2.THRESH_BINARY_INV)

# size
h, w = src.shape[:2]
dst = cv2.resize(dst, (w, h), interpolation=cv2.INTER_AREA)

cv2.copyTo(src, mask, dst)


if src is None or dst is None:
    print('이미지 리드 실패')
    sys.exit()
    
   
cv2.imshow('src', src)
# cv2.imshow('src_gray', src_gray)
cv2.imshow('dst', dst)
cv2.imshow('mask', mask)

cv2.waitKey()
cv2.destroyAllWindows()

# %%
src = cv2.imread('./fig2/cow.png')
dst = cv2.imread('./fig2/green.png')

## mask
src_gray = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)
_, mask = cv2.threshold(src_gray, 240, 255, cv2.THRESH_BINARY_INV)

# size
h, w = src.shape[:2]
dst_crop = dst[400:400+h, 400:400+w]


cv2.copyTo(src, mask, dst_crop)


if src is None or dst is None:
    print('이미지 리드 실패')
    sys.exit()
    
   
# cv2.imshow('src', src)
# cv2.imshow('src_gray', src_gray)
# cv2.imshow('mask', mask)
cv2.imshow('dst', dst)

cv2.waitKey()
cv2.destroyAllWindows()

# %%
src = cv2.imread('./fig2/puppy.bmp')
alpha = cv2.imread('./fig2/imgbin_sunglasses_1.png', cv2.IMREAD_UNCHANGED)
alpha = cv2.resize(alpha, (300, 150), interpolation=cv2.INTER_AREA)

sunglass = alpha[:, :, 0:3]
mask = alpha[:, :, -1]

src_crop = src[120:120+150, 220:220+300]

# cv2.copyTo(sunglass, mask, src_crop)
src_crop[mask > 0] = (0, 0, 255)

cv2.imshow('src', src)
# (x, y, w, h) = cv2.selectROI('src')
# cv2.imshow('src_crop', src_crop)
# cv2.imshow('alpha', alpha)
# cv2.imshow('mask', mask)
# cv2.imshow('sunglass', sunglass)

cv2.waitKey()
cv2.destroyAllWindows()

# %%
src = cv2.imread('./fig2/puppy2.png')
alpha = cv2.imread('./fig2/imgbin_hat.png', cv2.IMREAD_UNCHANGED)
alpha = cv2.resize(alpha, (350, 350), interpolation=cv2.INTER_AREA)

h, w = alpha.shape[:2]
sunglass = alpha[:, :, 0:-1]
mask = alpha[:, :, -1]

src_crop = src[40:40+h, 110:110+w]

cv2.copyTo(sunglass, mask, src_crop)
# src_crop[mask > 0] = (255, 0, 0)

# (x, y, w, h) = cv2.selectROI(src)
# print("ROI 좌표 (x, y, width, height):", x, y, w, h)

cv2.imshow('src', src)
# cv2.imshow('alpha', alpha)
# cv2.imshow('src_crop', src_crop)
# cv2.imshow('mask', mask)
# cv2.imshow('sunglass', sunglass)

cv2.waitKey()
cv2.destroyAllWindows()

# %%
src = cv2.imread('./fig2/ddolgi.png')
src = cv2.resize(src, (500, 800), interpolation=cv2.INTER_AREA)
alpha = cv2.imread('./fig2/imgbin_hat.png', cv2.IMREAD_UNCHANGED)
alpha = cv2.resize(alpha, (400, 500), interpolation=cv2.INTER_AREA)

# 회전 각도를 설정합니다.
angle = -15

# 이미지 중심점을 계산합니다.
height, width = alpha.shape[:2]
center = (width / 2, height / 2)

# 회전 변환 매트릭스를 생성합니다.
rotation_matrix = cv2.getRotationMatrix2D(center, angle, 1.0)

# 이미지를 회전합니다.
alpha = cv2.warpAffine(alpha, rotation_matrix, (width, height))

h, w = alpha.shape[:2]
sunglass = alpha[:, :, 0:-1]
mask = alpha[:, :, -1]

src_crop = src[280:280+h, 70:70+w]

cv2.copyTo(sunglass, mask, src_crop)

# (x, y, w, h) = cv2.selectROI(src)
# print("ROI 좌표 (x, y, width, height):", x, y, w, h)

cv2.imshow('src', src)
cv2.imshow('alpha', alpha)
# cv2.imshow('src_crop', src_crop)
# cv2.imshow('mask', mask)
# cv2.imshow('sunglass', sunglass)

cv2.waitKey()
cv2.destroyAllWindows()
